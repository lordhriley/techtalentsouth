# %% [markdown]
# Data Science Fundamentals: Python |
# [Table of Contents](../../index.ipynb)
# - - -
# <!--NAVIGATION-->
# Real World Examples: [Web Scraping](../web_scraping/01_rw_web_scraping.ipynb) | [Automation](../automation/02_rw_automation.ipynb) | [Messaging](../messaging/03_rw_messaging.ipynb) | [CSV](../csv/04_rw_csv.ipynb) | [Games](../games/05_games.ipynb) | **[Mobile](./06_mobile.ipynb)** | [Computer Vision](../computer_vision/08_computer_vision.ipynb) | [Chatbot](../chatbot/10_chatbot.ipynb) | [Built-In Database](../database/11_database.ipynb)
# - - -
# Life Examples: [COVID-19](../COVID-19/COVID-19_visualizations-plotly.ipynb) | [Police Brutality](https://maminian.github.io/brutality-map/) | [Spanish Flu](../spanishflu/index.ipynb)

# %% [markdown]
# # Creating Mobile Apps using Python

# %% [markdown]
# ## Using [Kivy](https://github.com/kivy/kivy)
#
# Kivy is an Open source Python library for rapid development of applications that make use of innovative user interfaces, such as multi-touch apps.
#
# - **Cross-Platforms**
#
# Kivy runs on Linux, Windows, OS X, Android, iOS, and Raspberry Pi. You can run the same code on all supported platforms. It can natively use most inputs, protocols and devices including WM_Touch, WM_Pen, Mac OS X Trackpad and Magic Mouse, Mtdev, Linux Kernel HID, TUIO. A multi-touch mouse simulator is included.
#
# - **Business-Friendly**
#
# Kivy is 100% free to use, under an MIT license (starting from 1.7.2) and LGPL 3 for the previous versions. The toolkit is professionally developed, backed and used. You can use it in a commercial product. The framework is stable and has a well documented API, plus a programming guide to help you get started.
#
# - **GPU Accelerated**
#
# The graphics engine is built over OpenGL ES 2, using a modern and fast graphics pipeline.  The toolkit comes with more than 20 widgets, all highly extensible. Many parts are written in C using Cython, and tested with regression tests.
#
#
# ***Sister development is [Buildozer](https://github.com/kivy/buildozer)***
#
# ### [See Documentation](https://buildmedia.readthedocs.org/media/pdf/kivy/latest/kivy.pdf)

# %% [markdown]
# - - -
# ## Installation

# %% [markdown]
# [Installation on Mac OS](https://kivy.org/doc/stable/installation/installation-osx.html)

# %% [markdown]
# [Installation on Windows 10+](https://kivy.org/doc/stable/installation/installation-windows.html)

# %% [markdown]
# - - -

# %% [markdown]
# ## App Packaging

# %% [markdown]
# [App Packaging For iOS](https://kivy.org/doc/stable/guide/packaging-ios.html)

# %% [markdown]
# [App Packaging For Android](https://kivy.org/doc/stable/guide/packaging-android.html) | [Download Kivy **Touchtracer** App From Google Play](https://play.google.com/store/apps/details?id=org.kivy.touchtracer)

# %% [markdown]
# - - -

# %%
pip install kivy
# Out:
# Collecting kivy
#   Downloading Kivy-1.11.1.tar.gz (23.6 MB)
#      |████████████████████████████████| 23.6 MB 3.9 MB/s eta 0:00:01    |███▊                            | 2.7 MB 841 kB/s eta 0:00:25
#     ERROR: Command errored out with exit status 1:
#      command: /usr/local/Cellar/jupyterlab/2.2.0/libexec/bin/python3.8 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/39/rw094bh97s1fm7lfmg_nwcxm0000gn/T/pip-install-slfg7by9/kivy/setup.py'"'"'; __file__='"'"'/private/var/folders/39/rw094bh97s1fm7lfmg_nwcxm0000gn/T/pip-install-slfg7by9/kivy/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/39/rw094bh97s1fm7lfmg_nwcxm0000gn/T/pip-pip-egg-info-enntp_xz
#          cwd: /private/var/folders/39/rw094bh97s1fm7lfmg_nwcxm0000gn/T/pip-install-slfg7by9/kivy/
#     Complete output (462 lines):
#     fatal: not a git repository (or any of the parent directories): .git
#       ERROR: Command errored out with exit status 1:
#        command: /usr/local/Cellar/jupyterlab/2.2.0/libexec/bin/python3.8 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/39/rw094bh97s1fm7lfmg_nwcxm0000gn/T/pip-wheel-lcx6zyg7/cython/setup.py'"'"'; __file__='"'"'/private/var/folders/39/rw094bh97s1fm7lfmg_nwcxm0000gn/T/pip-wheel-lcx6zyg7/cython/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/39/rw094bh97s1fm7lfmg_nwcxm0000gn/T/pip-wheel-5kvjdalu
#            cwd: /private/var/folders/39/rw094bh97s1fm7lfmg_nwcxm0000gn/T/pip-wheel-lcx6zyg7/cython/
#       Complete output (379 lines):
#       Unable to find pgen, not compiling formal grammar.
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-10.15-x86_64-3.8
#       copying cython.py -> build/lib.macosx-10.15-x86_64-3.8
#       creating build/lib.macosx-10.15-x86_64-3.8/Cython
#       copying Cython/TestUtils.py -> build/lib.macosx-10.15-x86_64-3.8/Cython
#       copying Cython/StringIOTree.py -> build/lib.macosx-10.15-x86_64-3.8/Cython
#       copying Cython/__init__.py -> build/lib.macosx-10.15-x86_64-3.8/Cython
#       copying Cython/Coverage.py -> build/lib.macosx-10.15-x86_64-3.8/Cython
#       copying Cython/Debugging.py -> build/lib.macosx-10.15-x86_64-3.8/Cython
#       copying Cython/Utils.py -> build/lib.macosx-10.15-x86_64-3.8/Cython
#       copying Cython/Shadow.py -> build/lib.macosx-10.15-x86_64-3.8/Cython
#       copying Cython/CodeWriter.py -> build/lib.macosx-10.15-x86_64-3.8/Cython
#       creating build/lib.macosx-10.15-x86_64-3.8/Cython/Build
#       copying Cython/Build/Cythonize.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Build
#       copying Cython/Build/__init__.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Build
#       copying Cython/Build/IpythonMagic.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Build
#       copying Cython/Build/BuildExecutable.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Build
#       copying Cython/Build/Distutils.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Build
#       copying Cython/Build/Dependencies.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Build
#       copying Cython/Build/Inline.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Build
#       creating build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/Optimize.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/Options.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/CodeGeneration.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/ModuleNode.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/DebugFlags.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/TypeSlots.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/Version.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/Parsing.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/Symtab.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/UtilNodes.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/Pythran.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/Naming.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/UtilityCode.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/TreePath.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/CmdLine.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/MemoryView.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/Code.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/__init__.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/TreeFragment.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/ParseTreeTransforms.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/Annotate.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/Lexicon.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/Interpreter.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/AutoDocTransforms.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/Visitor.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/Pipeline.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/Buffer.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/ExprNodes.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/CythonScope.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/Scanning.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/FusedNode.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/TypeInference.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/Builtin.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/Future.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/Errors.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/Nodes.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/Main.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/StringEncoding.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/AnalysedTreeTransforms.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/FlowControl.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/PyrexTypes.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       creating build/lib.macosx-10.15-x86_64-3.8/Cython/Runtime
#       copying Cython/Runtime/__init__.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Runtime
#       creating build/lib.macosx-10.15-x86_64-3.8/Cython/Distutils
#       copying Cython/Distutils/old_build_ext.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Distutils
#       copying Cython/Distutils/build_ext.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Distutils
#       copying Cython/Distutils/__init__.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Distutils
#       copying Cython/Distutils/extension.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Distutils
#       creating build/lib.macosx-10.15-x86_64-3.8/Cython/Debugger
#       copying Cython/Debugger/libcython.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Debugger
#       copying Cython/Debugger/__init__.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Debugger
#       copying Cython/Debugger/Cygdb.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Debugger
#       copying Cython/Debugger/DebugWriter.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Debugger
#       copying Cython/Debugger/libpython.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Debugger
#       creating build/lib.macosx-10.15-x86_64-3.8/Cython/Debugger/Tests
#       copying Cython/Debugger/Tests/test_libcython_in_gdb.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Debugger/Tests
#       copying Cython/Debugger/Tests/TestLibCython.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Debugger/Tests
#       copying Cython/Debugger/Tests/__init__.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Debugger/Tests
#       copying Cython/Debugger/Tests/test_libpython_in_gdb.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Debugger/Tests
#       creating build/lib.macosx-10.15-x86_64-3.8/Cython/Plex
#       copying Cython/Plex/Machines.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Plex
#       copying Cython/Plex/Actions.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Plex
#       copying Cython/Plex/__init__.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Plex
#       copying Cython/Plex/Timing.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Plex
#       copying Cython/Plex/Transitions.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Plex
#       copying Cython/Plex/Regexps.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Plex
#       copying Cython/Plex/DFA.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Plex
#       copying Cython/Plex/Errors.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Plex
#       copying Cython/Plex/Traditional.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Plex
#       copying Cython/Plex/Lexicons.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Plex
#       copying Cython/Plex/Scanners.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Plex
#       creating build/lib.macosx-10.15-x86_64-3.8/Cython/Tests
#       copying Cython/Tests/TestStringIOTree.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Tests
#       copying Cython/Tests/TestCodeWriter.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Tests
#       copying Cython/Tests/TestJediTyper.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Tests
#       copying Cython/Tests/xmlrunner.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Tests
#       copying Cython/Tests/__init__.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Tests
#       copying Cython/Tests/TestCythonUtils.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Tests
#       creating build/lib.macosx-10.15-x86_64-3.8/Cython/Build/Tests
#       copying Cython/Build/Tests/TestInline.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Build/Tests
#       copying Cython/Build/Tests/TestCyCache.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Build/Tests
#       copying Cython/Build/Tests/__init__.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Build/Tests
#       copying Cython/Build/Tests/TestIpythonMagic.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Build/Tests
#       copying Cython/Build/Tests/TestStripLiterals.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Build/Tests
#       creating build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler/Tests
#       copying Cython/Compiler/Tests/TestGrammar.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler/Tests
#       copying Cython/Compiler/Tests/TestCmdLine.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler/Tests
#       copying Cython/Compiler/Tests/TestSignatureMatching.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler/Tests
#       copying Cython/Compiler/Tests/TestTreeFragment.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler/Tests
#       copying Cython/Compiler/Tests/TestParseTreeTransforms.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler/Tests
#       copying Cython/Compiler/Tests/TestBuffer.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler/Tests
#       copying Cython/Compiler/Tests/TestUtilityLoad.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler/Tests
#       copying Cython/Compiler/Tests/TestFlowControl.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler/Tests
#       copying Cython/Compiler/Tests/__init__.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler/Tests
#       copying Cython/Compiler/Tests/TestTreePath.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler/Tests
#       copying Cython/Compiler/Tests/TestTypes.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler/Tests
#       copying Cython/Compiler/Tests/TestVisitor.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler/Tests
#       copying Cython/Compiler/Tests/TestMemView.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler/Tests
#       creating build/lib.macosx-10.15-x86_64-3.8/Cython/Utility
#       copying Cython/Utility/__init__.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Utility
#       creating build/lib.macosx-10.15-x86_64-3.8/Cython/Tempita
#       copying Cython/Tempita/__init__.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Tempita
#       copying Cython/Tempita/_looper.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Tempita
#       copying Cython/Tempita/_tempita.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Tempita
#       copying Cython/Tempita/compat3.py -> build/lib.macosx-10.15-x86_64-3.8/Cython/Tempita
#       creating build/lib.macosx-10.15-x86_64-3.8/pyximport
#       copying pyximport/pyximport.py -> build/lib.macosx-10.15-x86_64-3.8/pyximport
#       copying pyximport/__init__.py -> build/lib.macosx-10.15-x86_64-3.8/pyximport
#       copying pyximport/pyxbuild.py -> build/lib.macosx-10.15-x86_64-3.8/pyximport
#       creating build/lib.macosx-10.15-x86_64-3.8/Cython/Includes
#       copying Cython/Includes/openmp.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes
#       creating build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/posix
#       copying Cython/Includes/posix/types.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/posix
#       copying Cython/Includes/posix/select.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/posix
#       copying Cython/Includes/posix/resource.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/posix
#       copying Cython/Includes/posix/wait.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/posix
#       copying Cython/Includes/posix/stat.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/posix
#       copying Cython/Includes/posix/dlfcn.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/posix
#       copying Cython/Includes/posix/__init__.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/posix
#       copying Cython/Includes/posix/strings.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/posix
#       copying Cython/Includes/posix/stdio.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/posix
#       copying Cython/Includes/posix/stdlib.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/posix
#       copying Cython/Includes/posix/mman.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/posix
#       copying Cython/Includes/posix/ioctl.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/posix
#       copying Cython/Includes/posix/signal.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/posix
#       copying Cython/Includes/posix/fcntl.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/posix
#       copying Cython/Includes/posix/unistd.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/posix
#       copying Cython/Includes/posix/time.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/posix
#       creating build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libc
#       copying Cython/Includes/libc/locale.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libc
#       copying Cython/Includes/libc/__init__.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libc
#       copying Cython/Includes/libc/math.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libc
#       copying Cython/Includes/libc/limits.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libc
#       copying Cython/Includes/libc/setjmp.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libc
#       copying Cython/Includes/libc/string.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libc
#       copying Cython/Includes/libc/stdint.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libc
#       copying Cython/Includes/libc/stdio.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libc
#       copying Cython/Includes/libc/stdlib.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libc
#       copying Cython/Includes/libc/float.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libc
#       copying Cython/Includes/libc/signal.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libc
#       copying Cython/Includes/libc/stddef.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libc
#       copying Cython/Includes/libc/errno.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libc
#       copying Cython/Includes/libc/time.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libc
#       creating build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/numpy
#       copying Cython/Includes/numpy/__init__.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/numpy
#       copying Cython/Includes/numpy/math.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/numpy
#       creating build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/ref.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/long.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/iterator.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/weakref.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/cobject.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/set.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/__init__.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/object.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/slice.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/getargs.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/module.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/version.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/buffer.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/bytes.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/exc.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/int.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/mapping.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/string.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/ceval.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/dict.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/float.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/complex.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/array.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/function.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/sequence.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/method.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/oldbuffer.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/longintrepr.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/pycapsule.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/tuple.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/list.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/bytearray.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/pystate.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/mem.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/datetime.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/pythread.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/instance.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/pylifecycle.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/unicode.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/number.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/type.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       copying Cython/Includes/cpython/bool.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/cpython
#       creating build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libcpp
#       copying Cython/Includes/libcpp/unordered_set.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libcpp
#       copying Cython/Includes/libcpp/memory.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libcpp
#       copying Cython/Includes/libcpp/iterator.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libcpp
#       copying Cython/Includes/libcpp/set.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libcpp
#       copying Cython/Includes/libcpp/__init__.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libcpp
#       copying Cython/Includes/libcpp/limits.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libcpp
#       copying Cython/Includes/libcpp/deque.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libcpp
#       copying Cython/Includes/libcpp/stack.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libcpp
#       copying Cython/Includes/libcpp/string.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libcpp
#       copying Cython/Includes/libcpp/typeindex.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libcpp
#       copying Cython/Includes/libcpp/map.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libcpp
#       copying Cython/Includes/libcpp/complex.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libcpp
#       copying Cython/Includes/libcpp/vector.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libcpp
#       copying Cython/Includes/libcpp/functional.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libcpp
#       copying Cython/Includes/libcpp/algorithm.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libcpp
#       copying Cython/Includes/libcpp/list.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libcpp
#       copying Cython/Includes/libcpp/forward_list.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libcpp
#       copying Cython/Includes/libcpp/queue.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libcpp
#       copying Cython/Includes/libcpp/unordered_map.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libcpp
#       copying Cython/Includes/libcpp/cast.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libcpp
#       copying Cython/Includes/libcpp/typeinfo.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libcpp
#       copying Cython/Includes/libcpp/pair.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libcpp
#       copying Cython/Includes/libcpp/utility.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/libcpp
#       creating build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Includes/Deprecated/python_number.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Includes/Deprecated/python_unicode.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Includes/Deprecated/python_dict.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Includes/Deprecated/python_mem.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Includes/Deprecated/stl.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Includes/Deprecated/python_method.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Includes/Deprecated/python_pycapsule.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Includes/Deprecated/python_oldbuffer.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Includes/Deprecated/python_complex.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Includes/Deprecated/python_bytes.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Includes/Deprecated/python_iterator.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Includes/Deprecated/python_long.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Includes/Deprecated/stdio.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Includes/Deprecated/stdlib.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Includes/Deprecated/python_float.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Includes/Deprecated/python_buffer.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Includes/Deprecated/python_mapping.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Includes/Deprecated/python_instance.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Includes/Deprecated/python_int.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Includes/Deprecated/python_exc.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Includes/Deprecated/python_string.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Includes/Deprecated/python_object.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Includes/Deprecated/python_bool.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Includes/Deprecated/python_module.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Includes/Deprecated/python_set.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Includes/Deprecated/python_getargs.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Includes/Deprecated/python_type.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Includes/Deprecated/python_version.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Includes/Deprecated/python_tuple.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Includes/Deprecated/python_weakref.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Includes/Deprecated/python_ref.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Includes/Deprecated/python_cobject.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Includes/Deprecated/python_function.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Includes/Deprecated/python_sequence.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Includes/Deprecated/python.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Includes/Deprecated/python_list.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Includes/Deprecated
#       copying Cython/Compiler/ParseTreeTransforms.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/Scanning.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/Parsing.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/FlowControl.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/Code.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Compiler/Visitor.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Compiler
#       copying Cython/Runtime/refnanny.pyx -> build/lib.macosx-10.15-x86_64-3.8/Cython/Runtime
#       copying Cython/Debugger/Tests/codefile -> build/lib.macosx-10.15-x86_64-3.8/Cython/Debugger/Tests
#       copying Cython/Debugger/Tests/cfuncs.c -> build/lib.macosx-10.15-x86_64-3.8/Cython/Debugger/Tests
#       copying Cython/Plex/Scanners.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Plex
#       copying Cython/Plex/Actions.pxd -> build/lib.macosx-10.15-x86_64-3.8/Cython/Plex
#       copying Cython/Utility/CpdefEnums.pyx -> build/lib.macosx-10.15-x86_64-3.8/Cython/Utility
#       copying Cython/Utility/TestCyUtilityLoader.pyx -> build/lib.macosx-10.15-x86_64-3.8/Cython/Utility
#       copying Cython/Utility/CppConvert.pyx -> build/lib.macosx-10.15-x86_64-3.8/Cython/Utility
#       copying Cython/Utility/TestCythonScope.pyx -> build/lib.macosx-10.15-x86_64-3.8/Cython/Utility
#       copying Cython/Utility/MemoryView.pyx -> build/lib.macosx-10.15-x86_64-3.8/Cython/Utility
#       copying Cython/Utility/CConvert.pyx -> build/lib.macosx-10.15-x86_64-3.8/Cython/Utility
#       copying Cython/Utility/ObjectHandling.c -> build/lib.macosx-10.15-x86_64-3.8/Cython/Utility
#       copying Cython/Utility/Buffer.c -> build/lib.macosx-10.15-x86_64-3.8/Cython/Utility
#       copying Cython/Utility/Builtins.c -> build/lib.macosx-10.15-x86_64-3.8/Cython/Utility
#       copying Cython/Utility/Overflow.c -> build/lib.macosx-10.15-x86_64-3.8/Cython/Utility
#       copying Cython/Utility/Capsule.c -> build/lib.macosx-10.15-x86_64-3.8/Cython/Utility
#       copying Cython/Utility/FunctionArguments.c -> build/lib.macosx-10.15-x86_64-3.8/Cython/Utility
#       copying Cython/Utility/TestUtilityLoader.c -> build/lib.macosx-10.15-x86_64-3.8/Cython/Utility
#       copying Cython/Utility/MemoryView_C.c -> build/lib.macosx-10.15-x86_64-3.8/Cython/Utility
#       copying Cython/Utility/Printing.c -> build/lib.macosx-10.15-x86_64-3.8/Cython/Utility
#       copying Cython/Utility/CythonFunction.c -> build/lib.macosx-10.15-x86_64-3.8/Cython/Utility
#       copying Cython/Utility/Complex.c -> build/lib.macosx-10.15-x86_64-3.8/Cython/Utility
#       copying Cython/Utility/StringTools.c -> build/lib.macosx-10.15-x86_64-3.8/Cython/Utility
#       copying Cython/Utility/ImportExport.c -> build/lib.macosx-10.15-x86_64-3.8/Cython/Utility
#       copying Cython/Utility/CMath.c -> build/lib.macosx-10.15-x86_64-3.8/Cython/Utility
#       copying Cython/Utility/CommonStructures.c -> build/lib.macosx-10.15-x86_64-3.8/Cython/Utility
#       copying Cython/Utility/Embed.c -> build/lib.macosx-10.15-x86_64-3.8/Cython/Utility
#       copying Cython/Utility/ExtensionTypes.c -> build/lib.macosx-10.15-x86_64-3.8/Cython/Utility
#       copying Cython/Utility/Optimize.c -> build/lib.macosx-10.15-x86_64-3.8/Cython/Utility
#       copying Cython/Utility/ModuleSetupCode.c -> build/lib.macosx-10.15-x86_64-3.8/Cython/Utility
#       copying Cython/Utility/Profile.c -> build/lib.macosx-10.15-x86_64-3.8/Cython/Utility
#       copying Cython/Utility/Exceptions.c -> build/lib.macosx-10.15-x86_64-3.8/Cython/Utility
#       copying Cython/Utility/AsyncGen.c -> build/lib.macosx-10.15-x86_64-3.8/Cython/Utility
#       copying Cython/Utility/TypeConversion.c -> build/lib.macosx-10.15-x86_64-3.8/Cython/Utility
#       copying Cython/Utility/Coroutine.c -> build/lib.macosx-10.15-x86_64-3.8/Cython/Utility
#       copying Cython/Utility/arrayarray.h -> build/lib.macosx-10.15-x86_64-3.8/Cython/Utility
#       copying Cython/Utility/CppSupport.cpp -> build/lib.macosx-10.15-x86_64-3.8/Cython/Utility
#       running build_ext
#       building 'Cython.Plex.Scanners' extension
#       creating build/temp.macosx-10.15-x86_64-3.8
#       creating build/temp.macosx-10.15-x86_64-3.8/private
#       creating build/temp.macosx-10.15-x86_64-3.8/private/var
#       creating build/temp.macosx-10.15-x86_64-3.8/private/var/folders
#       creating build/temp.macosx-10.15-x86_64-3.8/private/var/folders/39
#       creating build/temp.macosx-10.15-x86_64-3.8/private/var/folders/39/rw094bh97s1fm7lfmg_nwcxm0000gn
#       creating build/temp.macosx-10.15-x86_64-3.8/private/var/folders/39/rw094bh97s1fm7lfmg_nwcxm0000gn/T
#       creating build/temp.macosx-10.15-x86_64-3.8/private/var/folders/39/rw094bh97s1fm7lfmg_nwcxm0000gn/T/pip-wheel-lcx6zyg7
#       creating build/temp.macosx-10.15-x86_64-3.8/private/var/folders/39/rw094bh97s1fm7lfmg_nwcxm0000gn/T/pip-wheel-lcx6zyg7/cython
#       creating build/temp.macosx-10.15-x86_64-3.8/private/var/folders/39/rw094bh97s1fm7lfmg_nwcxm0000gn/T/pip-wheel-lcx6zyg7/cython/Cython
#       creating build/temp.macosx-10.15-x86_64-3.8/private/var/folders/39/rw094bh97s1fm7lfmg_nwcxm0000gn/T/pip-wheel-lcx6zyg7/cython/Cython/Plex
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -isysroot /Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk -I/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/usr/include -I/Library/Developer/CommandLineTools/SDKs/MacOSX10.15.sdk/System/Library/Frameworks/Tk.framework/Versions/8.5/Headers -arch x86_64 -I/usr/local/opt/python@3.8/Frameworks/Python.framework/Versions/3.8/include/python3.8 -c /private/var/folders/39/rw094bh97s1fm7lfmg_nwcxm0000gn/T/pip-wheel-lcx6zyg7/cython/Cython/Plex/Scanners.c -o build/temp.macosx-10.15-x86_64-3.8/private/var/folders/39/rw094bh97s1fm7lfmg_nwcxm0000gn/T/pip-wheel-lcx6zyg7/cython/Cython/Plex/Scanners.o
#       /private/var/folders/39/rw094bh97s1fm7lfmg_nwcxm0000gn/T/pip-wheel-lcx6zyg7/cython/Cython/Plex/Scanners.c:7241:257: error: too many arguments to function call, expected 15, have 16
#         __pyx_codeobj__6 = (PyObject*)__Pyx_PyCode_New(1, 0, 1, 0, CO_OPTIMIZED|CO_NEWLOCALS, __pyx_empty_bytes, __pyx_empty_tuple, __pyx_empty_tuple, __pyx_tuple__5, __pyx_empty_tuple, __pyx_empty_tuple, __pyx_kp_s_Cython_Plex_Scanners_py, __pyx_n_s_read, 113, __pyx_empty_bytes); if (unlikely(!__pyx_codeobj__6)) __PYX_ERR(0, 113, __pyx_L1_error)
#                                       ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~
#       /private/var/folders/39/rw094bh97s1fm7lfmg_nwcxm0000gn/T/pip-wheel-lcx6zyg7/cython/Cython/Plex/Scanners.c:333:82: note: expanded from macro '__Pyx_PyCode_New'
#                 PyCode_New(a, 0, k, l, s, f, code, c, n, v, fv, cell, fn, name, fline, lnos)
#                 ~~~~~~~~~~                                                             ^~~~
#       /usr/local/opt/python@3.8/Frameworks/Python.framework/Versions/3.8/include/python3.8/code.h:122:12: note: 'PyCode_New' declared here
#       PyAPI_FUNC(PyCodeObject *) PyCode_New(
#                  ^
#       /private/var/folders/39/rw094bh97s1fm7lfmg_nwcxm0000gn/T/pip-wheel-lcx6zyg7/cython/Cython/Plex/Scanners.c:7253:261: error: too many arguments to function call, expected 15, have 16
#         __pyx_codeobj__8 = (PyObject*)__Pyx_PyCode_New(1, 0, 1, 0, CO_OPTIMIZED|CO_NEWLOCALS, __pyx_empty_bytes, __pyx_empty_tuple, __pyx_empty_tuple, __pyx_tuple__7, __pyx_empty_tuple, __pyx_empty_tuple, __pyx_kp_s_Cython_Plex_Scanners_py, __pyx_n_s_position, 297, __pyx_empty_bytes); if (unlikely(!__pyx_codeobj__8)) __PYX_ERR(0, 297, __pyx_L1_error)
#                                       ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~
#       /private/var/folders/39/rw094bh97s1fm7lfmg_nwcxm0000gn/T/pip-wheel-lcx6zyg7/cython/Cython/Plex/Scanners.c:333:82: note: expanded from macro '__Pyx_PyCode_New'
#                 PyCode_New(a, 0, k, l, s, f, code, c, n, v, fv, cell, fn, name, fline, lnos)
#                 ~~~~~~~~~~                                                             ^~~~
#       /usr/local/opt/python@3.8/Frameworks/Python.framework/Versions/3.8/include/python3.8/code.h:122:12: note: 'PyCode_New' declared here
#       PyAPI_FUNC(PyCodeObject *) PyCode_New(
#                  ^
#       /private/var/folders/39/rw094bh97s1fm7lfmg_nwcxm0000gn/T/pip-wheel-lcx6zyg7/cython/Cython/Plex/Scanners.c:7265:266: error: too many arguments to function call, expected 15, have 16
#         __pyx_codeobj__10 = (PyObject*)__Pyx_PyCode_New(1, 0, 1, 0, CO_OPTIMIZED|CO_NEWLOCALS, __pyx_empty_bytes, __pyx_empty_tuple, __pyx_empty_tuple, __pyx_tuple__9, __pyx_empty_tuple, __pyx_empty_tuple, __pyx_kp_s_Cython_Plex_Scanners_py, __pyx_n_s_get_position, 308, __pyx_empty_bytes); if (unlikely(!__pyx_codeobj__10)) __PYX_ERR(0, 308, __pyx_L1_error)
#                                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~
#       /private/var/folders/39/rw094bh97s1fm7lfmg_nwcxm0000gn/T/pip-wheel-lcx6zyg7/cython/Cython/Plex/Scanners.c:333:82: note: expanded from macro '__Pyx_PyCode_New'
#                 PyCode_New(a, 0, k, l, s, f, code, c, n, v, fv, cell, fn, name, fline, lnos)
#                 ~~~~~~~~~~                                                             ^~~~
#       /usr/local/opt/python@3.8/Frameworks/Python.framework/Versions/3.8/include/python3.8/code.h:122:12: note: 'PyCode_New' declared here
#       PyAPI_FUNC(PyCodeObject *) PyCode_New(
#                  ^
#       /private/var/folders/39/rw094bh97s1fm7lfmg_nwcxm0000gn/T/pip-wheel-lcx6zyg7/cython/Cython/Plex/Scanners.c:7277:258: error: too many arguments to function call, expected 15, have 16
#         __pyx_codeobj__12 = (PyObject*)__Pyx_PyCode_New(1, 0, 1, 0, CO_OPTIMIZED|CO_NEWLOCALS, __pyx_empty_bytes, __pyx_empty_tuple, __pyx_empty_tuple, __pyx_tuple__11, __pyx_empty_tuple, __pyx_empty_tuple, __pyx_kp_s_Cython_Plex_Scanners_py, __pyx_n_s_eof, 334, __pyx_empty_bytes); if (unlikely(!__pyx_codeobj__12)) __PYX_ERR(0, 334, __pyx_L1_error)
#                                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~
#       /private/var/folders/39/rw094bh97s1fm7lfmg_nwcxm0000gn/T/pip-wheel-lcx6zyg7/cython/Cython/Plex/Scanners.c:333:82: note: expanded from macro '__Pyx_PyCode_New'
#                 PyCode_New(a, 0, k, l, s, f, code, c, n, v, fv, cell, fn, name, fline, lnos)
#                 ~~~~~~~~~~                                                             ^~~~
#       /usr/local/opt/python@3.8/Frameworks/Python.framework/Versions/3.8/include/python3.8/code.h:122:12: note: 'PyCode_New' declared here
#       PyAPI_FUNC(PyCodeObject *) PyCode_New(
#                  ^
#       /private/var/folders/39/rw094bh97s1fm7lfmg_nwcxm0000gn/T/pip-wheel-lcx6zyg7/cython/Cython/Plex/Scanners.c:10053:9: error: too many arguments to function call, expected 15, have 16
#               __pyx_empty_bytes  /*PyObject *lnotab*/
#               ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       /private/var/folders/39/rw094bh97s1fm7lfmg_nwcxm0000gn/T/pip-wheel-lcx6zyg7/cython/Cython/Plex/Scanners.c:333:82: note: expanded from macro '__Pyx_PyCode_New'
#                 PyCode_New(a, 0, k, l, s, f, code, c, n, v, fv, cell, fn, name, fline, lnos)
#                 ~~~~~~~~~~                                                             ^~~~
#       /usr/local/opt/python@3.8/Frameworks/Python.framework/Versions/3.8/include/python3.8/code.h:122:12: note: 'PyCode_New' declared here
#       PyAPI_FUNC(PyCodeObject *) PyCode_New(
#                  ^
#       5 errors generated.
#       error: command 'clang' failed with exit status 1
#       ----------------------------------------
#       ERROR: Failed building wheel for cython
#     ERROR: Failed to build one or more wheels
#      Traceback (most recent call last):
#        File "/usr/local/Cellar/jupyterlab/2.2.0/libexec/lib/python3.8/site-packages/setuptools/installer.py", line 128, in fetch_build_egg
#          subprocess.check_call(cmd)
#        File "/usr/local/opt/python@3.8/Frameworks/Python.framework/Versions/3.8/lib/python3.8/subprocess.py", line 364, in check_call
#          raise CalledProcessError(retcode, cmd)
#      subprocess.CalledProcessError: Command '['/usr/local/Cellar/jupyterlab/2.2.0/libexec/bin/python3.8', '-m', 'pip', '--disable-pip-version-check', 'wheel', '--no-deps', '-w', '/var/folders/39/rw094bh97s1fm7lfmg_nwcxm0000gn/T/tmpuqekxap5', '--quiet', '--find-links', 'https://github.com/kivy-garden/garden/archive/master.zip', 'cython!=0.27,!=0.27.2,<=0.29.10,>=0.24']' returned non-zero exit status 1.
#
#      The above exception was the direct cause of the following exception:
#
#      Traceback (most recent call last):
#        File "<string>", line 1, in <module>
#        File "/private/var/folders/39/rw094bh97s1fm7lfmg_nwcxm0000gn/T/pip-install-slfg7by9/kivy/setup.py", line 1073, in <module>
#          setup(
#        File "/usr/local/Cellar/jupyterlab/2.2.0/libexec/lib/python3.8/site-packages/setuptools/__init__.py", line 164, in setup
#          _install_setup_requires(attrs)
#        File "/usr/local/Cellar/jupyterlab/2.2.0/libexec/lib/python3.8/site-packages/setuptools/__init__.py", line 159, in _install_setup_requires
#          dist.fetch_build_eggs(dist.setup_requires)
#        File "/usr/local/Cellar/jupyterlab/2.2.0/libexec/lib/python3.8/site-packages/setuptools/dist.py", line 699, in fetch_build_eggs
#          resolved_dists = pkg_resources.working_set.resolve(
#        File "/usr/local/Cellar/jupyterlab/2.2.0/libexec/lib/python3.8/site-packages/pkg_resources/__init__.py", line 779, in resolve
#          dist = best[req.key] = env.best_match(
#        File "/usr/local/Cellar/jupyterlab/2.2.0/libexec/lib/python3.8/site-packages/pkg_resources/__init__.py", line 1064, in best_match
#          return self.obtain(req, installer)
#        File "/usr/local/Cellar/jupyterlab/2.2.0/libexec/lib/python3.8/site-packages/pkg_resources/__init__.py", line 1076, in obtain
#          return installer(requirement)
#        File "/usr/local/Cellar/jupyterlab/2.2.0/libexec/lib/python3.8/site-packages/setuptools/dist.py", line 758, in fetch_build_egg
#          return fetch_build_egg(self, req)
#        File "/usr/local/Cellar/jupyterlab/2.2.0/libexec/lib/python3.8/site-packages/setuptools/installer.py", line 130, in fetch_build_egg
#          raise DistutilsError(str(e)) from e
#      distutils.errors.DistutilsError: Command '['/usr/local/Cellar/jupyterlab/2.2.0/libexec/bin/python3.8', '-m', 'pip', '--disable-pip-version-check', 'wheel', '--no-deps', '-w', '/var/folders/39/rw094bh97s1fm7lfmg_nwcxm0000gn/T/tmpuqekxap5', '--quiet', '--find-links', 'https://github.com/kivy-garden/garden/archive/master.zip', 'cython!=0.27,!=0.27.2,<=0.29.10,>=0.24']' returned non-zero exit status 1.
#     Using setuptools
#     User distribution detected, avoid portable command.
#     Using this graphics system: OpenGL ES 2
#     OSX framework used, force to x86_64 only
#     OSX ARCHFLAGS are: -arch x86_64
#     GStreamer framework not found, fallback on pkg-config
#     WARNING: A problem occurred while running pkg-config --libs --cflags gstreamer-1.0 (code 1)
#
#     b"Package gstreamer-1.0 was not found in the pkg-config search path.\nPerhaps you should add the directory containing `gstreamer-1.0.pc'\nto the PKG_CONFIG_PATH environment variable\nNo package 'gstreamer-1.0' found\n"
#
#     Missing framework /Library/Frameworks/SDL2.framework
#     Missing framework /Library/Frameworks/SDL2_ttf.framework
#     Missing framework /Library/Frameworks/SDL2_image.framework
#     Missing framework /Library/Frameworks/SDL2_mixer.framework
#     SDL2 frameworks not found, fallback on pkg-config
#     WARNING: A problem occurred while running pkg-config --libs --cflags sdl2 SDL2_ttf SDL2_image SDL2_mixer (code 1)
#
#     b"Package sdl2 was not found in the pkg-config search path.\nPerhaps you should add the directory containing `sdl2.pc'\nto the PKG_CONFIG_PATH environment variable\nNo package 'sdl2' found\nPackage SDL2_ttf was not found in the pkg-config search path.\nPerhaps you should add the directory containing `SDL2_ttf.pc'\nto the PKG_CONFIG_PATH environment variable\nNo package 'SDL2_ttf' found\nPackage SDL2_image was not found in the pkg-config search path.\nPerhaps you should add the directory containing `SDL2_image.pc'\nto the PKG_CONFIG_PATH environment variable\nNo package 'SDL2_image' found\nPackage SDL2_mixer was not found in the pkg-config search path.\nPerhaps you should add the directory containing `SDL2_mixer.pc'\nto the PKG_CONFIG_PATH environment variable\nNo package 'SDL2_mixer' found\n"
#
#     Xcode detected at b'/Library/Developer/CommandLineTools', and using OS X10.15 sdk
#     WARNING: A problem occurred while running pkg-config --libs --cflags pangoft2 (code 1)
#
#     b"Package pangoft2 was not found in the pkg-config search path.\nPerhaps you should add the directory containing `pangoft2.pc'\nto the PKG_CONFIG_PATH environment variable\nNo package 'pangoft2' found\n"
#
#     ERROR: Dependency for context.pyx not resolved: config.pxi
#     ERROR: Dependency for compiler.pyx not resolved: config.pxi
#     ERROR: Dependency for context_instructions.pyx not resolved: config.pxi
#     ERROR: Dependency for fbo.pyx not resolved: config.pxi
#     ERROR: Dependency for gl_instructions.pyx not resolved: config.pxi
#     ERROR: Dependency for instructions.pyx not resolved: config.pxi
#     ERROR: Dependency for opengl.pyx not resolved: config.pxi
#     ERROR: Dependency for opengl_utils.pyx not resolved: config.pxi
#     ERROR: Dependency for shader.pyx not resolved: config.pxi
#     ERROR: Dependency for stencil_instructions.pyx not resolved: config.pxi
#     ERROR: Dependency for scissor_instructions.pyx not resolved: config.pxi
#     ERROR: Dependency for texture.pyx not resolved: config.pxi
#     ERROR: Dependency for vbo.pyx not resolved: config.pxi
#     ERROR: Dependency for vertex.pyx not resolved: config.pxi
#     ERROR: Dependency for vertex_instructions.pyx not resolved: config.pxi
#     ERROR: Dependency for cgl.pyx not resolved: config.pxi
#     ERROR: Dependency for cgl_mock.pyx not resolved: config.pxi
#     ERROR: Dependency for cgl_gl.pyx not resolved: config.pxi
#     ERROR: Dependency for cgl_glew.pyx not resolved: config.pxi
#     ERROR: Dependency for cgl_sdl2.pyx not resolved: config.pxi
#     ERROR: Dependency for svg.pyx not resolved: config.pxi
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# WARNING: You are using pip version 20.1.1; however, version 20.2.2 is available.
# You should consider upgrading via the '/usr/local/Cellar/jupyterlab/2.2.0/libexec/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Find the the following python program `files/firstkivy.py` from the `files/` location.

# %% [raw]
# import kivy
# kivy.require('1.0.0')
#
# from kivy.app import App
# from kivy.uix.button import Button
#
# class MyApp(App):
#     def build(self):
#         return Button(text='Hello World')
#
# if __name__ in ('__android__', '__main__'):
#     MyApp().run()

# %% [markdown]
# - - -
# <!--NAVIGATION-->
# Real World Examples: [Web Scraping](../web_scraping/01_rw_web_scraping.ipynb) | [Automation](../automation/02_rw_automation.ipynb) | [Messaging](../messaging/03_rw_messaging.ipynb) | [CSV](../csv/04_rw_csv.ipynb) | [Games](../games/05_games.ipynb) | **[Mobile](./06_mobile.ipynb)** | [Feature Engineering](../feature_engineering/07_feature-engineering.ipynb) | [Computer Vision](../computer_vision/08_computer_vision.ipynb) | [Chatbot](../chatbot/10_chatbot.ipynb)

# %% [markdown]
# - - -
#
# Copyright © 2020 Qualex Consulting Services Incorporated.
