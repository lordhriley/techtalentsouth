# %% [markdown]
# Data Science Fundamentals: Python |
# [Table of Contents](../index.ipynb)
# - - -
# <!--NAVIGATION-->
# Module 9. | **[Introduction to NumPy](./01_introduction_NumPy.ipynb)** | [The Basics](./02_basics_NumPy.ipynb) | [Exercises](./03_NumPy_exercises.ipynb)

# %% [markdown]
# - - -
#
# ## Using [Poetry](https://python-poetry.org/) for Python Package Installation
# **(Optional)**

# %% [markdown]
# [Poetry](https://python-poetry.org/) is a tool for dependency management and packaging in Python. It allows you to declare the libraries your project depends on and it will manage (install/update) them for you.

# %% [markdown]
# ### Develop
#
# Poetry comes with all the tools you might need to manage your projects in a deterministic way.

# %% [markdown]
# ![develop](files/develop_poetry.png)

# %% [markdown]
# ### Build
#
# Easily build and package your projects with a single command.

# %% [markdown]
# ![build](files/build_poetry.png)

# %% [markdown]
# ### Publish
#
# Make your work known by publishing it to PyPI

# %% [markdown]
# ![publish](files/publish_poetry.png)

# %% [markdown]
# ### Track

# %% [markdown]
# Having an insight of your project's dependencies is just one command away.

# %% [markdown]
# ![track](files/track_poetry.png)

# %% [markdown]
# ### Installation of Poetry

# %%
pip install poetry
# Out:
# Collecting poetry
#   Downloading poetry-1.0.10-py2.py3-none-any.whl (224 kB)
#      |████████████████████████████████| 224 kB 916 kB/s eta 0:00:01
# Collecting html5lib<2.0,>=1.0
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 6.4 MB/s eta 0:00:01
# Collecting cachecontrol[filecache]<0.13.0,>=0.12.4
#   Using cached CacheControl-0.12.6-py2.py3-none-any.whl (19 kB)
# Collecting cleo<0.8.0,>=0.7.6
#   Using cached cleo-0.7.6-py2.py3-none-any.whl (21 kB)
# Collecting pyrsistent<0.15.0,>=0.14.2
#   Using cached pyrsistent-0.14.11.tar.gz (104 kB)
# Requirement already satisfied: pexpect<5.0.0,>=4.7.0 in /usr/local/Cellar/jupyterlab/2.2.0/libexec/lib/python3.8/site-packages (from poetry) (4.8.0)
# Requirement already satisfied: pyparsing<3.0,>=2.2 in /usr/local/Cellar/jupyterlab/2.2.0/libexec/lib/python3.8/site-packages (from poetry) (2.4.7)
# Collecting shellingham<2.0,>=1.1
#   Using cached shellingham-1.3.2-py2.py3-none-any.whl (11 kB)
# Collecting pkginfo<2.0,>=1.4
#   Using cached pkginfo-1.5.0.1-py2.py3-none-any.whl (25 kB)
# Collecting tomlkit<0.6.0,>=0.5.11
#   Using cached tomlkit-0.5.11-py2.py3-none-any.whl (31 kB)
# Collecting cachy<0.4.0,>=0.3.0
#   Using cached cachy-0.3.0-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: requests<3.0,>=2.18 in /usr/local/Cellar/jupyterlab/2.2.0/libexec/lib/python3.8/site-packages (from poetry) (2.24.0)
# Collecting keyring<21.0.0,>=20.0.1; python_version >= "3.5" and python_version < "4.0"
#   Using cached keyring-20.0.1-py2.py3-none-any.whl (31 kB)
# Collecting requests-toolbelt<0.9.0,>=0.8.0
#   Using cached requests_toolbelt-0.8.0-py2.py3-none-any.whl (54 kB)
# Requirement already satisfied: jsonschema<4.0,>=3.1 in /usr/local/Cellar/jupyterlab/2.2.0/libexec/lib/python3.8/site-packages (from poetry) (3.2.0)
# Collecting clikit<0.5.0,>=0.4.2
#   Using cached clikit-0.4.3-py2.py3-none-any.whl (88 kB)
# Requirement already satisfied: six>=1.9 in /usr/local/Cellar/jupyterlab/2.2.0/libexec/lib/python3.8/site-packages (from html5lib<2.0,>=1.0->poetry) (1.15.0)
# Requirement already satisfied: webencodings in /usr/local/Cellar/jupyterlab/2.2.0/libexec/lib/python3.8/site-packages (from html5lib<2.0,>=1.0->poetry) (0.5.1)
# Collecting msgpack>=0.5.2
#   Downloading msgpack-1.0.0-cp38-cp38-macosx_10_13_x86_64.whl (78 kB)
#      |████████████████████████████████| 78 kB 4.8 MB/s eta 0:00:01
# Collecting lockfile>=0.9; extra == "filecache"
#   Using cached lockfile-0.12.2-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/Cellar/jupyterlab/2.2.0/libexec/lib/python3.8/site-packages (from pexpect<5.0.0,>=4.7.0->poetry) (0.6.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/Cellar/jupyterlab/2.2.0/libexec/lib/python3.8/site-packages (from requests<3.0,>=2.18->poetry) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/Cellar/jupyterlab/2.2.0/libexec/lib/python3.8/site-packages (from requests<3.0,>=2.18->poetry) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/Cellar/jupyterlab/2.2.0/libexec/lib/python3.8/site-packages (from requests<3.0,>=2.18->poetry) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/Cellar/jupyterlab/2.2.0/libexec/lib/python3.8/site-packages (from requests<3.0,>=2.18->poetry) (2020.6.20)
# Requirement already satisfied: setuptools in /usr/local/Cellar/jupyterlab/2.2.0/libexec/lib/python3.8/site-packages (from jsonschema<4.0,>=3.1->poetry) (49.2.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/Cellar/jupyterlab/2.2.0/libexec/lib/python3.8/site-packages (from jsonschema<4.0,>=3.1->poetry) (19.3.0)
# Collecting pylev<2.0,>=1.3
#   Using cached pylev-1.3.0-py2.py3-none-any.whl (4.9 kB)
# Collecting pastel<0.3.0,>=0.2.0
#   Using cached pastel-0.2.0-py2.py3-none-any.whl (6.0 kB)
# Building wheels for collected packages: pyrsistent
#   Building wheel for pyrsistent (setup.py) ... done
#   Created wheel for pyrsistent: filename=pyrsistent-0.14.11-cp38-cp38-macosx_10_15_x86_64.whl size=67282 sha256=eddc99971d75ca90e0480adebb3c86e31e7d6b2996702162542f609c47e9a579
#   Stored in directory: /Users/gsjackson/Library/Caches/pip/wheels/89/c3/aa/0e12ac315752ef08ad0690f7ca965880b9b6b7d0e628463d1e
# Successfully built pyrsistent
# Installing collected packages: html5lib, msgpack, lockfile, cachecontrol, pylev, pastel, clikit, cleo, pyrsistent, shellingham, pkginfo, tomlkit, cachy, keyring, requests-toolbelt, poetry
#   Attempting uninstall: pyrsistent
#     Found existing installation: pyrsistent 0.16.0
#     Uninstalling pyrsistent-0.16.0:
#       Successfully uninstalled pyrsistent-0.16.0
# Successfully installed cachecontrol-0.12.6 cachy-0.3.0 cleo-0.7.6 clikit-0.4.3 html5lib-1.1 keyring-20.0.1 lockfile-0.12.2 msgpack-1.0.0 pastel-0.2.0 pkginfo-1.5.0.1 poetry-1.0.10 pylev-1.3.0 pyrsistent-0.14.11 requests-toolbelt-0.8.0 shellingham-1.3.2 tomlkit-0.5.11
# WARNING: You are using pip version 20.1.1; however, version 20.2 is available.
# You should consider upgrading via the '/usr/local/Cellar/jupyterlab/2.2.0/libexec/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# **Linux / MacOS Installation**

# %% [raw]
# curl -sSL https://raw.githubusercontent.com/python-poetry/poetry/master/get-poetry.py | python

# %% [markdown]
# **Windows Powershell Installation**
#
# Run as Administrator

# %% [raw]
# (Invoke-WebRequest -Uri https://raw.githubusercontent.com/python-poetry/poetry/master/get-poetry.py -UseBasicParsing).Content | python

# %% [markdown]
# The installer installs the poetry tool to Poetry's bin directory. On Unix it is located at ```$HOME/.poetry/bin``` and on Windows at ```%USERPROFILE%\.poetry\bin```.

# %%
poetry --version
# Out:
# ----------------------------------------------------------
# NameError                Traceback (most recent call last)
# <ipython-input-1-4666e7fa95ae> in <module>
# ----> 1 poetry --version
#
# NameError: name 'poetry' is not defined

# %% [markdown]
# ### Creation of a Python Package with Poetry

# %% [markdown]
# Create a package with Poetry, run ```poetry new``` along with the name of the directory that will house the package:

# %% [raw]
# cd datascience/python/09_mod_numpy
#
# poetry new flake8-markdown

# %% [markdown]
# See directory structure below:

# %% [markdown]
# ![poetry directory](files/poetry_directory.png)

# %% [markdown]
# ### Customizing Python Package with Poetry

# %% [markdown]
# Here's the initial ```pyproject.toml``` file:

# %% [markdown]
# ![pyproject.toml](files/poetry_pyproject_initial.png)

# %% [markdown]
# Here's the finished ```pyproject.toml``` file:

# %% [markdown]
# ![pyproject.toml](files/poetry_pyproject_customized.png)

# %% [markdown]
# ### Build a Python Package with Poetry

# %% [markdown]
# #### TestPyPI
#
# TestPyPI is "a separate instance of the Python Package Index that allows you to try distribution tools and processes without affecting the real index". Uploading packages to TestPyPI and installing from there can help package maintainers avoid shipping broken versions of their packages.

# %% [markdown]
# First, build the package:

# %% [raw]
# poetry build

# %% [markdown]
# #### Test Package Build

# %% [markdown]
# Must [create a TestPyPI Registration](https://test.pypi.org/account/register/) before uploading packages to the test package index.

# %% [raw]
# poetry config repositories.testpypi https://test.pypi.org/legacy/

# %% [markdown]
# Publish the package to Test PyPI:

# %% [raw]
# $ poetry publish -r testpypi
#
# Publishing flake8-markdown (0.1.1) to testpypi
# Username:
# Password:
#
#  - Uploading flake8-markdown-0.1.1.tar.gz 100%
#  - Uploading flake8_markdown-0.1.1-py3-none-any.whl 100%

# %% [markdown]
# Finally, verify that the package looks and works as intended by viewing it on [testpypi.pypi.org](testpypi.pypi.org) and installing the test version in a separate virtual environment:

# %%
pip install --index-url https://test.pypi.org/simple/ flake8-markdown

# %% [markdown]
# #### Formal Package Build
# **PyPI**

# %% [markdown]
# Must [create a PyPI Account](https://pypi.org/account/register/) before uploading packages to the PyPI package index.

# %% [markdown]
# If the package looks great on Test PyPI and works to boot, publishing to PyPI is as easy as:

# %% [raw]
# poetry publish

# %% [markdown]
# # Introduction to NumPy

# %% [markdown]
# **What is a Python NumPy?**
#
# NumPy is a Python package which stands for ‘Numerical Python’. It is the core library for scientific computing, which contains a powerful n-dimensional array object, provide tools for integrating C, C++ etc. It is also useful in linear algebra, random number capability etc. NumPy array can also be used as an efficient multi-dimensional container for generic data. Now, let me tell you what exactly is a python numpy array.
#
# **NumPy Array**: Numpy array is a powerful N-dimensional array object which is in the form of rows and columns. We can initialize numpy arrays from nested Python lists and access it elements.
#
# - - -

# %% [markdown]
# This chapter outlines techniques for effectively loading, storing, and manipulating in-memory data in Python.
# The topic is very broad: datasets can come from a wide range of sources and a wide range of formats, including be collections of documents, collections of images, collections of sound clips, collections of numerical measurements, or nearly anything else.
# Despite this apparent heterogeneity, it will help us to think of all data fundamentally as arrays of numbers.
#
# For example, images–particularly digital images–can be thought of as simply two-dimensional arrays of numbers representing pixel brightness across the area.
# Sound clips can be thought of as one-dimensional arrays of intensity versus time.
# Text can be converted in various ways into numerical representations, perhaps binary digits representing the frequency of certain words or pairs of words.
# No matter what the data are, the first step in making it analyzable will be to transform them into arrays of numbers.
#
# For this reason, efficient storage and manipulation of numerical arrays is absolutely fundamental to the process of doing data science.
# We'll now take a look at the specialized tools that Python has for handling such numerical arrays: the NumPy package.
#
# This chapter will cover NumPy in detail. NumPy (short for *Numerical Python*) provides an efficient interface to store and operate on dense data buffers.
# In some ways, NumPy arrays are like Python's built-in ``list`` type, but NumPy arrays provide much more efficient storage and data operations as the arrays grow larger in size.
# NumPy arrays form the core of nearly the entire ecosystem of data science tools in Python, so time spent learning to use NumPy effectively will be valuable no matter what aspect of data science interests you.
#
# If you followed the advice outlined in the Preface and installed the Anaconda stack, you already have NumPy installed and ready to go.

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in /usr/local/Cellar/jupyterlab/2.2.0/libexec/lib/python3.8/site-packages (1.18.5)
# WARNING: You are using pip version 20.1.1; however, version 20.2 is available.
# You should consider upgrading via the '/usr/local/Cellar/jupyterlab/2.2.0/libexec/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Using NumPy

# %% [markdown]
# If you're more the do-it-yourself type, you can go to http://www.numpy.org/ and follow the installation instructions found there.
# Once you do, you can import NumPy and double-check the version:

# %%
import numpy
numpy.__version__
# Out:
# '1.18.5'

# %% [markdown]
# For the pieces of the package discussed here, I'd recommend NumPy version 1.8 or later.
# By convention, you'll find that most people in the SciPy/PyData world will import NumPy using ``np`` as an alias:

# %%
import numpy as np

# %% [markdown]
# This is the way we will import and use NumPy.

# %% [markdown]
# ## Reminder about Built In Documentation
#
# As you read through this chapter, don't forget that IPython gives you the ability to quickly explore the contents of a package (by using the tab-completion feature), as well as the documentation of various functions (using the ``?`` character – Refer back to [Help and Documentation in IPython](01.01-Help-And-Documentation.ipynb)).
#
# For example, to display all the contents of the numpy namespace, you can type this:
#
# ```ipython
# In [3]: np.<TAB>
# ```
#
# And to display NumPy's built-in documentation, you can use this:
#
# ```ipython
# In [4]: np?
# ```
#
# More detailed documentation, along with tutorials and other resources, can be found at http://www.numpy.org.

# %%
np.

# %%
np?

# %% [markdown]
# - - -
# <!--NAVIGATION-->
# Module 9. | **[Introduction to NumPy](./01_introduction_NumPy.ipynb)** | [The Basics](02_basics_NumPy.ipynb) | [Exercises](./03_NumPy_exercises.ipynb)
# <br>
# [Top](#)

# %% [markdown]
# - - -
#
# Copyright © 2020 Qualex Consulting Services Incorporated.
