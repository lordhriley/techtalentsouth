# %% [markdown]
# Data Science Fundamentals: R |
# [Table of Contents](../index.ipynb)
# - - -
# <!--NAVIGATION-->
# Module 13. [Introduction](./00.ipynb) | [Basic Syntax](./01.ipynb)  | [Data Types](./02.ipynb) | [Variables](./03.ipynb) | [Operators](./04.ipynb) | [Decision Making](./05.ipynb)  | [Functions](./06.ipynb) | [Strings](./07.ipynb) | [Vectors](./08.ipynb) | [Lists](./09.ipynb) | [Matrices](./10.ipynb) | [Arrays](./11.ipynb) | [Factors](./12.ipynb) | [Data Frames](./13.ipynb) | [Data Reshaping](./14.ipynb) | [Exercises](./15.ipynb)

# %% [markdown]
# # Introduction of R

# %% [markdown]
# ![slide1](images/slide1.png)

# %% [markdown]
# ![image](images/slide2.png)

# %% [markdown]
# ![images](images/slide3.png)

# %% [markdown]
# ![image](images/slide4.png)

# %% [markdown]
# ![image](images/slide5.png)

# %% [markdown]
# # Installation of R

# %% [markdown]
# ## Starting R

# %%
When using Mac OS, submit the following from any terminal session -

# %% [raw]
# open -a /Applications/R.app

# %% [markdown]
# ## Packages

# %% [markdown]
# R packages are a collection of R functions, complied code and sample data. They are stored under a directory called "library" in the R environment. By default, R installs a set of packages during installation. More packages are added later, when they are needed for some specific purpose. When we start the R console, only the default packages are available by default. Other packages which are already installed have to be loaded explicitly to be used by the R program that is going to use them.
#
# All the packages available in R language are listed at R Packages.
#
# ![packages](images/slide6.png)
#
# Below is a list of commands to be used to check, verify and use the R packages.

# %%
installed.packages()
# Out:
#              Package      LibPath
# BH           BH           /usr/local/anaconda3/envs/TTS-R/lib/R/library
# DBI          DBI          /usr/local/anaconda3/envs/TTS-R/lib/R/library
# IRdisplay    IRdisplay    /usr/local/anaconda3/envs/TTS-R/lib/R/library
# IRkernel     IRkernel     /usr/local/anaconda3/envs/TTS-R/lib/R/library
# KernSmooth   KernSmooth   /usr/local/anaconda3/envs/TTS-R/lib/R/library
# MASS         MASS         /usr/local/anaconda3/envs/TTS-R/lib/R/library
# Matrix       Matrix       /usr/local/anaconda3/envs/TTS-R/lib/R/library
# ModelMetrics ModelMetrics /usr/local/anaconda3/envs/TTS-R/lib/R/library
# PKI          PKI          /usr/local/anaconda3/envs/TTS-R/lib/R/library
# R6           R6           /usr/local/anaconda3/envs/TTS-R/lib/R/library
# RColorBrewer RColorBrewer /usr/local/anaconda3/envs/TTS-R/lib/R/library
# RCurl        RCurl        /usr/local/anaconda3/envs/TTS-R/lib/R/library
# RJDBC        RJDBC        /usr/local/anaconda3/envs/TTS-R/lib/R/library
# RJSONIO      RJSONIO      /usr/local/anaconda3/envs/TTS-R/lib/R/library
# Rcpp         Rcpp         /usr/local/anaconda3/envs/TTS-R/lib/R/library
# RcppRoll     RcppRoll     /usr/local/anaconda3/envs/TTS-R/lib/R/library
# SQUAREM      SQUAREM      /usr/local/anaconda3/envs/TTS-R/lib/R/library
# TTR          TTR          /usr/local/anaconda3/envs/TTS-R/lib/R/library
# askpass      askpass      /usr/local/anaconda3/envs/TTS-R/lib/R/library
# assertthat   assertthat   /usr/local/anaconda3/envs/TTS-R/lib/R/library
# backports    backports    /usr/local/anaconda3/envs/TTS-R/lib/R/library
# base         base         /usr/local/anaconda3/envs/TTS-R/lib/R/library
# base64enc    base64enc    /usr/local/anaconda3/envs/TTS-R/lib/R/library
# bit          bit          /usr/local/anaconda3/envs/TTS-R/lib/R/library
# bit64        bit64        /usr/local/anaconda3/envs/TTS-R/lib/R/library
# bitops       bitops       /usr/local/anaconda3/envs/TTS-R/lib/R/library
# blob         blob         /usr/local/anaconda3/envs/TTS-R/lib/R/library
# boot         boot         /usr/local/anaconda3/envs/TTS-R/lib/R/library
# broom        broom        /usr/local/anaconda3/envs/TTS-R/lib/R/library
# caTools      caTools      /usr/local/anaconda3/envs/TTS-R/lib/R/library
# ...          ...          ...
# sourcetools  sourcetools  /usr/local/anaconda3/envs/TTS-R/lib/R/library
# sparklyr     sparklyr     /usr/local/anaconda3/envs/TTS-R/lib/R/library
# spatial      spatial      /usr/local/anaconda3/envs/TTS-R/lib/R/library
# splines      splines      /usr/local/anaconda3/envs/TTS-R/lib/R/library
# stats        stats        /usr/local/anaconda3/envs/TTS-R/lib/R/library
# stats4       stats4       /usr/local/anaconda3/envs/TTS-R/lib/R/library
# stringi      stringi      /usr/local/anaconda3/envs/TTS-R/lib/R/library
# stringr      stringr      /usr/local/anaconda3/envs/TTS-R/lib/R/library
# survival     survival     /usr/local/anaconda3/envs/TTS-R/lib/R/library
# sys          sys          /usr/local/anaconda3/envs/TTS-R/lib/R/library
# tcltk        tcltk        /usr/local/anaconda3/envs/TTS-R/lib/R/library
# tibble       tibble       /usr/local/anaconda3/envs/TTS-R/lib/R/library
# tidyr        tidyr        /usr/local/anaconda3/envs/TTS-R/lib/R/library
# tidyselect   tidyselect   /usr/local/anaconda3/envs/TTS-R/lib/R/library
# tidyverse    tidyverse    /usr/local/anaconda3/envs/TTS-R/lib/R/library
# timeDate     timeDate     /usr/local/anaconda3/envs/TTS-R/lib/R/library
# tinytex      tinytex      /usr/local/anaconda3/envs/TTS-R/lib/R/library
# tools        tools        /usr/local/anaconda3/envs/TTS-R/lib/R/library
# utf8         utf8         /usr/local/anaconda3/envs/TTS-R/lib/R/library
# utils        utils        /usr/local/anaconda3/envs/TTS-R/lib/R/library
# uuid         uuid         /usr/local/anaconda3/envs/TTS-R/lib/R/library
# viridisLite  viridisLite  /usr/local/anaconda3/envs/TTS-R/lib/R/library
# whisker      whisker      /usr/local/anaconda3/envs/TTS-R/lib/R/library
# withr        withr        /usr/local/anaconda3/envs/TTS-R/lib/R/library
# xfun         xfun         /usr/local/anaconda3/envs/TTS-R/lib/R/library
# xml2         xml2         /usr/local/anaconda3/envs/TTS-R/lib/R/library
# xtable       xtable       /usr/local/anaconda3/envs/TTS-R/lib/R/library
# xts          xts          /usr/local/anaconda3/envs/TTS-R/lib/R/library
# yaml         yaml         /usr/local/anaconda3/envs/TTS-R/lib/R/library
# zoo          zoo          /usr/local/anaconda3/envs/TTS-R/lib/R/library
#              Version   Priority
# BH           1.69.0-1  NA
# DBI          1.0.0     NA
# IRdisplay    0.7.0     NA
# IRkernel     0.8.15    NA
# KernSmooth   2.23-15   recommended
# MASS         7.3-51.3  NA
# Matrix       1.2-17    NA
# ModelMetrics 1.2.2     NA
# PKI          0.1-5.1   NA
# R6           2.4.0     NA
# RColorBrewer 1.1-2     NA
# RCurl        1.95-4.12 NA
# RJDBC        0.2-7.1   NA
# RJSONIO      1.3-1.1   NA
# Rcpp         1.0.1     NA
# RcppRoll     0.3.0     NA
# SQUAREM      2017.10-1 NA
# TTR          0.23-4    NA
# askpass      1.0       NA
# assertthat   0.2.1     NA
# backports    1.1.4     NA
# base         3.6.1     base
# base64enc    0.1-3     NA
# bit          1.1-14    NA
# bit64        0.9-7     NA
# bitops       1.0-6     NA
# blob         1.1.1     NA
# boot         1.3-20    recommended
# broom        0.5.2     NA
# caTools      1.17.1.2  NA
# ...          ...       ...
# sourcetools  0.1.7     NA
# sparklyr     1.0.0     NA
# spatial      7.3-11    NA
# splines      3.6.1     base
# stats        3.6.1     base
# stats4       3.6.1     base
# stringi      1.4.3     NA
# stringr      1.4.0     NA
# survival     2.44-1.1  NA
# sys          3.2       NA
# tcltk        3.6.1     base
# tibble       2.1.1     NA
# tidyr        0.8.3     NA
# tidyselect   0.2.5     NA
# tidyverse    1.2.1     NA
# timeDate     3043.102  NA
# tinytex      0.12      NA
# tools        3.6.1     base
# utf8         1.1.4     NA
# utils        3.6.1     base
# uuid         0.1-2     NA
# viridisLite  0.3.0     NA
# whisker      0.3-2     NA
# withr        2.1.2     NA
# xfun         0.6       NA
# xml2         1.2.0     NA
# xtable       1.8-4     NA
# xts          0.11-2    NA
# yaml         2.2.0     NA
# zoo          1.8-6     NA
#              Depends
# BH           NA
# DBI          R (>= 3.0.0), methods
# IRdisplay    R (>= 3.0.1)
# IRkernel     R (>= 3.2.0)
# KernSmooth   R (>= 2.5.0), stats
# MASS         R (>= 3.1.0), grDevices, graphics, stats, utils
# Matrix       R (>= 3.2.0)
# ModelMetrics R (>= 3.2.2)
# PKI          R (>= 2.9.0), base64enc
# R6           R (>= 3.0)
# RColorBrewer R (>= 2.0.0)
# RCurl        R (>= 3.0.0), methods, bitops
# RJDBC        methods, DBI, rJava (>= 0.4-15), R (>= 2.4.0)
# RJSONIO      NA
# Rcpp         R (>= 3.0.0)
# RcppRoll     R (>= 2.15.1)
# SQUAREM      R (>= 3.0)
# TTR          NA
# askpass      NA
# assertthat   NA
# backports    R (>= 3.0.0)
# base         NA
# base64enc    R (>= 2.9.0)
# bit          R (>= 2.9.2)
# bit64        R (>= 3.0.1), bit (>= 1.1-12), utils, methods, stats
# bitops       NA
# blob         NA
# boot         R (>= 3.0.0), graphics, stats
# broom        R (>= 3.1)
# caTools      R (>= 2.2.0)
# ...          ...
# sourcetools  R (>= 3.0.2)
# sparklyr     R (>= 3.2)
# spatial      R (>= 3.0.0), graphics, stats, utils
# splines      NA
# stats        NA
# stats4       NA
# stringi      R (>= 2.14)
# stringr      R (>= 3.1)
# survival     R (>= 2.13.0)
# sys          NA
# tcltk        NA
# tibble       R (>= 3.1.0)
# tidyr        R (>= 3.1)
# tidyselect   R (>= 3.1)
# tidyverse    NA
# timeDate     R (>= 2.15.1), graphics, utils, stats, methods
# tinytex      NA
# tools        NA
# utf8         R (>= 2.10)
# utils        NA
# uuid         R (>= 2.9.0)
# viridisLite  R (>= 2.10)
# whisker      NA
# withr        R (>= 3.0.2)
# xfun         NA
# xml2         R (>= 3.1.0)
# xtable       R (>= 2.10.0)
# xts          zoo (>= 1.7-12)
# yaml         NA
# zoo          R (>= 3.1.0), stats
#              Imports
# BH           NA
# DBI          NA
# IRdisplay    methods, repr
# IRkernel     repr (>= 0.4.99),\nmethods,\nevaluate (>= 0.10),\nIRdisplay (>= 0.3.0.9999),\npbdZMQ (>= 0.2-1),\ncrayon,\njsonlite (>= 0.9.6),\nuuid,\ndigest
# KernSmooth   NA
# MASS         methods
# Matrix       methods, graphics, grid, stats, utils, lattice
# ModelMetrics Rcpp, data.table
# PKI          NA
# R6           NA
# RColorBrewer NA
# RCurl        NA
# RJDBC        NA
# RJSONIO      methods
# Rcpp         methods, utils
# RcppRoll     Rcpp
# SQUAREM      NA
# TTR          xts (>= 0.10-0), zoo, curl
# askpass      sys (>= 2.1)
# assertthat   tools
# backports    utils
# base         NA
# base64enc    NA
# bit          NA
# bit64        NA
# bitops       NA
# blob         methods, prettyunits
# boot         NA
# broom        backports, dplyr, generics (>= 0.0.2), methods, nlme, purrr,\nreshape2, stringr, tibble, tidyr
# caTools      bitops
# ...          ...
# sourcetools  NA
# sparklyr     assertthat, base64enc, config (>= 0.2), DBI (>= 0.6-1), dplyr\n(>= 0.7.2), dbplyr (>= 1.1.0), digest, forge, generics, httr\n(>= 1.2.1), jsonlite (>= 1.4), methods, openssl (>= 0.8),\npurrr, r2d3, rappdirs, rlang (>= 0.1.4), rprojroot, rstudioapi\n(>= 0.6), tibble, tidyr, withr, xml2, ellipsis (>= 0.1.0)
# spatial      NA
# splines      graphics, stats
# stats        utils, grDevices, graphics
# stats4       graphics, methods, stats
# stringi      tools, utils, stats
# stringr      glue (>= 1.2.0), magrittr, stringi (>= 1.1.7)
# survival     graphics, Matrix, methods, splines, stats, utils
# sys          NA
# tcltk        utils
# tibble       cli (>= 1.0.1), crayon (>= 1.3.4), fansi (>= 0.4.0), methods,\npillar (>= 1.3.1), pkgconfig (>= 2.0.2), rlang (>= 0.3.1),\nutils
# tidyr        dplyr (>= 0.7.0), glue, magrittr, purrr, Rcpp, rlang, stringi,\ntibble, tidyselect (>= 0.2.5), utils
# tidyselect   glue (>= 1.3.0), purrr, rlang (>= 0.2.2), Rcpp (>= 0.12.0)
# tidyverse    broom (>= 0.4.2), cli (>= 1.0.0), crayon (>= 1.3.4), dplyr (>=\n0.7.4), dbplyr (>= 1.1.0), forcats (>= 0.2.0), ggplot2 (>=\n2.2.1), haven (>= 1.1.0), hms (>= 0.3), httr (>= 1.3.1),\njsonlite (>= 1.5), lubridate (>= 1.7.1), magrittr (>= 1.5),\nmodelr (>= 0.1.1), purrr (>= 0.2.4), readr (>= 1.1.1), readxl\n(>= 1.0.0), reprex (>= 0.1.1), rlang (>= 0.1.4), rstudioapi (>=\n0.7), rvest (>= 0.3.2), stringr (>= 1.2.0), tibble (>= 1.3.4),\ntidyr (>= 0.7.2), xml2 (>= 1.1.1)
# timeDate     NA
# tinytex      xfun (>= 0.5)
# tools        NA
# utf8         NA
# utils        NA
# uuid         NA
# viridisLite  NA
# whisker      NA
# withr        stats, graphics, grDevices
# xfun         tools
# xml2         Rcpp
# xtable       stats, utils
# xts          methods
# yaml         NA
# zoo          utils, graphics, grDevices, lattice (>= 0.20-27)
#              LinkingTo
# BH           NA
# DBI          NA
# IRdisplay    NA
# IRkernel     NA
# KernSmooth   NA
# MASS         NA
# Matrix       NA
# ModelMetrics Rcpp
# PKI          NA
# R6           NA
# RColorBrewer NA
# RCurl        NA
# RJDBC        NA
# RJSONIO      NA
# Rcpp         NA
# RcppRoll     Rcpp
# SQUAREM      NA
# TTR          xts
# askpass      NA
# assertthat   NA
# backports    NA
# base         NA
# base64enc    NA
# bit          NA
# bit64        NA
# bitops       NA
# blob         NA
# boot         NA
# broom        NA
# caTools      NA
# ...          ...
# sourcetools  NA
# sparklyr     NA
# spatial      NA
# splines      NA
# stats        NA
# stats4       NA
# stringi      NA
# stringr      NA
# survival     NA
# sys          NA
# tcltk        NA
# tibble       NA
# tidyr        Rcpp
# tidyselect   Rcpp (>= 0.12.0),
# tidyverse    NA
# timeDate     NA
# tinytex      NA
# tools        NA
# utf8         NA
# utils        NA
# uuid         NA
# viridisLite  NA
# whisker      NA
# withr        NA
# xfun         NA
# xml2         Rcpp (>= 0.12.12)
# xtable       NA
# xts          zoo
# yaml         NA
# zoo          NA
#              Suggests
# BH           NA
# DBI          blob, covr, hms, knitr, magrittr, rprojroot, rmarkdown,\nRSQLite (>= 1.1-2), testthat, xml2
# IRdisplay    testthat, withr
# IRkernel     testthat,\nroxygen2
# KernSmooth   MASS
# MASS         lattice, nlme, nnet, survival
# Matrix       expm, MASS
# ModelMetrics testthat
# ...
# withr        testthat, covr, lattice, DBI, RSQLite, methods, knitr,\nrmarkdown
# xfun         testit, parallel, rstudioapi, tinytex, mime, markdown, knitr,\nhtmltools, base64enc, remotes, rmarkdown
# xml2         testthat, curl, covr, knitr, rmarkdown, magrittr, httr
# xtable       knitr, plm, zoo, survival
# xts          timeSeries, timeDate, tseries, chron, fts, tis, RUnit
# yaml         RUnit
# zoo          coda, chron, DAAG, fts, ggplot2, mondate, scales,\nstrucchange, timeDate, timeSeries, tis, tseries, xts
#              Enhances
# BH           NA
# DBI          NA
# IRdisplay    NA
# IRkernel     NA
# KernSmooth   NA
# MASS         NA
# Matrix       MatrixModels, graph, SparseM, sfsmisc
# ModelMetrics NA
# PKI          gmp
# R6           NA
# RColorBrewer NA
# RCurl        NA
# RJDBC        NA
# RJSONIO      NA
# Rcpp         NA
# RcppRoll     NA
# SQUAREM      NA
# TTR          quantmod
# askpass      NA
# assertthat   NA
# backports    NA
# base         NA
# base64enc    png
# bit          NA
# bit64        NA
# bitops       NA
# blob         NA
# boot         NA
# broom        NA
# caTools      NA
# ...          ...
# sourcetools  NA
# sparklyr     NA
# spatial      NA
# splines      NA
# stats        NA
# stats4       NA
# stringi      NA
# stringr      NA
# survival     NA
# sys          NA
# tcltk        NA
# tibble       NA
# tidyr        NA
# tidyselect   NA
# tidyverse    NA
# timeDate     NA
# tinytex      NA
# tools        NA
# utf8         NA
# utils        NA
# uuid         NA
# viridisLite  NA
# whisker      NA
# withr        NA
# xfun         NA
# xml2         NA
# xtable       NA
# xts          NA
# yaml         NA
# zoo          NA
#              License                                License_is_FOSS
# BH           BSL-1.0                                NA
# DBI          LGPL (>= 2)                            NA
# IRdisplay    MIT + file LICENSE                     NA
# IRkernel     MIT + file LICENSE                     NA
# KernSmooth   Unlimited                              NA
# MASS         GPL-2 | GPL-3                          NA
# Matrix       GPL (>= 2) | file LICENCE              NA
# ModelMetrics GPL (>= 2)                             NA
# PKI          GPL-2 | GPL-3 | file LICENSE           NA
# R6           MIT + file LICENSE                     NA
# RColorBrewer Apache License 2.0                     NA
# RCurl        BSD                                    NA
# RJDBC        MIT + file LICENSE                     NA
# RJSONIO      BSD_3_clause + file LICENSE            NA
# Rcpp         GPL (>= 2)                             NA
# RcppRoll     GPL (>= 2)                             NA
# SQUAREM      GPL (>= 2)                             NA
# TTR          GPL-2                                  NA
# askpass      MIT + file LICENSE                     NA
# assertthat   GPL-3                                  NA
# backports    GPL-2                                  NA
# base         Part of R 3.6.1                        NA
# base64enc    GPL-2 | GPL-3                          NA
# bit          GPL-2                                  NA
# bit64        GPL-2                                  NA
# bitops       GPL (>= 2)                             NA
# blob         GPL-3                                  NA
# boot         Unlimited                              NA
# broom        MIT + file LICENSE                     NA
# caTools      GPL-3                                  NA
# ...          ...                                    ...
# sourcetools  MIT + file LICENSE                     NA
# sparklyr     Apache License 2.0 | file LICENSE      NA
# spatial      GPL-2 | GPL-3                          NA
# splines      Part of R 3.6.1                        NA
# stats        Part of R 3.6.1                        NA
# stats4       Part of R 3.6.1                        NA
# stringi      file LICENSE                           yes
# stringr      GPL-2 | file LICENSE                   NA
# survival     LGPL (>= 2)                            NA
# sys          MIT + file LICENSE                     NA
# tcltk        Part of R 3.6.1                        NA
# tibble       MIT + file LICENSE                     NA
# tidyr        MIT + file LICENSE                     NA
# tidyselect   GPL-3                                  NA
# tidyverse    GPL-3 | file LICENSE                   NA
# timeDate     GPL (>= 2)                             NA
# tinytex      MIT + file LICENSE                     NA
# tools        Part of R 3.6.1                        NA
# utf8         Apache License (== 2.0) | file LICENSE NA
# utils        Part of R 3.6.1                        NA
# uuid         MIT + file LICENSE                     NA
# viridisLite  MIT + file LICENSE                     NA
# whisker      GPL-3                                  NA
# withr        GPL (>= 2)                             NA
# xfun         MIT + file LICENSE                     NA
# xml2         GPL (>= 2)                             NA
# xtable       GPL (>= 2)                             NA
# xts          GPL (>= 2)                             NA
# yaml         BSD_3_clause + file LICENSE            NA
# zoo          GPL-2 | GPL-3                          NA
#              License_restricts_use OS_type MD5sum NeedsCompilation Built
# BH           NA                    NA      NA     no               3.6.0
# DBI          NA                    NA      NA     no               3.6.0
# IRdisplay    NA                    NA      NA     no               3.6.0
# IRkernel     NA                    NA      NA     NA               3.6.0
# KernSmooth   NA                    NA      NA     yes              3.6.0
# MASS         NA                    NA      NA     yes              3.6.0
# Matrix       NA                    NA      NA     yes              3.6.0
# ModelMetrics NA                    NA      NA     yes              3.6.0
# PKI          NA                    NA      NA     yes              3.6.0
# R6           NA                    NA      NA     no               3.6.0
# RColorBrewer NA                    NA      NA     no               3.6.0
# RCurl        NA                    NA      NA     yes              3.6.0
# RJDBC        NA                    NA      NA     no               3.6.0
# RJSONIO      NA                    NA      NA     yes              3.6.0
# Rcpp         NA                    NA      NA     yes              3.6.0
# RcppRoll     NA                    NA      NA     yes              3.6.0
# SQUAREM      NA                    NA      NA     no               3.6.0
# TTR          NA                    NA      NA     yes              3.6.0
# askpass      NA                    NA      NA     yes              3.6.0
# assertthat   NA                    NA      NA     no               3.6.0
# backports    NA                    NA      NA     yes              3.6.0
# base         NA                    NA      NA     NA               3.6.1
# base64enc    NA                    NA      NA     yes              3.6.0
# bit          NA                    NA      NA     yes              3.6.0
# bit64        NA                    NA      NA     yes              3.6.0
# bitops       NA                    NA      NA     yes              3.6.0
# blob         NA                    NA      NA     no               3.6.0
# boot         NA                    NA      NA     no               3.6.0
# broom        NA                    NA      NA     no               3.6.0
# caTools      NA                    NA      NA     yes              3.6.0
# ...          ...                   ...     ...    ...              ...
# sourcetools  NA                    NA      NA     yes              3.6.0
# sparklyr     NA                    NA      NA     no               3.6.0
# spatial      NA                    NA      NA     yes              3.6.0
# splines      NA                    NA      NA     yes              3.6.1
# stats        NA                    NA      NA     yes              3.6.1
# stats4       NA                    NA      NA     NA               3.6.1
# stringi      NA                    NA      NA     yes              3.6.0
# stringr      NA                    NA      NA     no               3.6.0
# survival     NA                    NA      NA     yes              3.6.0
# sys          NA                    NA      NA     yes              3.6.0
# tcltk        NA                    NA      NA     yes              3.6.1
# tibble       NA                    NA      NA     yes              3.6.0
# tidyr        NA                    NA      NA     yes              3.6.0
# tidyselect   NA                    NA      NA     yes              3.6.0
# tidyverse    NA                    NA      NA     no               3.6.0
# timeDate     NA                    NA      NA     no               3.6.0
# tinytex      NA                    NA      NA     no               3.6.0
# tools        NA                    NA      NA     yes              3.6.1
# utf8         NA                    NA      NA     yes              3.6.0
# utils        NA                    NA      NA     yes              3.6.1
# uuid         NA                    NA      NA     yes              3.6.0
# viridisLite  NA                    NA      NA     no               3.6.0
# whisker      NA                    NA      NA     no               3.6.0
# withr        NA                    NA      NA     no               3.6.0
# xfun         NA                    NA      NA     no               3.6.0
# xml2         NA                    NA      NA     yes              3.6.0
# xtable       NA                    NA      NA     no               3.6.0
# xts          NA                    NA      NA     yes              3.6.0
# yaml         NA                    NA      NA     yes              3.6.0
# zoo          NA                    NA      NA     yes              3.6.1

# %% [markdown]
# Check Available R Packages
# ---
#
# Get library locations containing R packages

# %%
.libPaths()
# Out:
# [1] "/Library/Frameworks/R.framework/Versions/3.6/Resources/library"

# %% [markdown]
# Get the list of all the packages installed
# ---

# %%
library()

# %% [markdown]
# Get all packages currently loaded in the R environment
# ---

# %%
search()
# Out:
#  [1] ".GlobalEnv"        "jupyter:irkernel"  "package:stats"
#  [4] "package:graphics"  "package:grDevices" "package:utils"
#  [7] "package:datasets"  "package:methods"   "Autoloads"
# [10] "package:base"

# %% [markdown]
# Install a New Package
# ---
#
# There are two ways to add new R packages. One is installing directly from the CRAN directory and another is downloading the package to your local system and installing it manually.
#
# <b>Install Packages Directly from Cran</b>
#
# The following command gets the packages directly from CRAN webpage and installs the package in the R environment. You may be prompted to choose a nearest mirror. Choose the one appropriate to your location.

# %% [raw]
#  install.packages("Package Name")
#
# # Install the package named "XML".
#
#  install.packages("XML")

# %%
install.packages("xml2")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %% [markdown]
# <b>Install Packages Manually</b>

# %% [markdown]
# [View Packages](https://cran.r-project.org/web/packages/available_packages_by_name.html)
#
# [View Documentation](https://cran.r-project.org/doc/manuals/r-release/R-admin.html)

# %% [markdown]
# Save the package as a .zip file in a suitable location in the local system.
#
# Now you can run the following command to install this package in the R environment.

# %% [raw]
# install.packages(file_name_with_path, repos = NULL, type = "source")
#
# # Install the package named "XML"
#
# install.packages("E:/XML_3.98-1.3.zip", repos = NULL, type = "source")

# %% [markdown]
# Load Package to Library
# ---
#
# Before a package can be used in the code, it must be loaded to the current R environment. You also need to load a package that is already installed previously but not available in the current environment.
#
# A package is loaded using the following command −

# %% [raw]
# library("package Name", lib.loc = "path to library")
#
# # Load the package named "XML"
#
# install.packages("E:/XML_3.98-1.3.zip", repos = NULL, type = "source")

# %% [markdown]
# Troubleshooting
# ---
#
# When you install packages in R with Mac OS X (10.9), if you get this warning:

# %% [raw]
# tar: Failed to set default locale

# %% [markdown]
# In shell you have LANG set to en_US and LC_ALL set to en_US.UTF-8.

# %% [markdown]
# This command seems to fix it:

# %% [raw]
# defaults write org.R-project.R force.LANG en_US.UTF-8

# %% [markdown]
# ![caption](files/fix.png)

# %% [markdown]
# After restarting R, no more warnings about the default locale.

# %% [markdown]
# Most Common R Packages
# ---

# %% [markdown]
# ![caption](files/packages.jpg)

# %% [markdown]
# Submit the following code / function to install load multiple packages at once

# %% [raw]
# # ipak function: install and load multiple R packages.
# # check to see if packages are installed. Install them if they are not, then load them into the R session.
# # LSMeans, Comparision, RegTest, ACD, Bison
# ipak <- function(pkg){
#     new.pkg <- pkg[!(pkg %in% installed.packages()[, "Package"])]
#     if (length(new.pkg))
#         install.packages(new.pkg, dependencies = TRUE)
#     sapply(pkg, require, character.only = TRUE)
# }
#
# # usage
# packages <- c("ggplot2", "plyr", "reshape2", "RColorBrewer", "scales", "grid")
#
# #pre-modeling stage
# #packages
#
# #modeling stage
# #packages
#
# #post modeling stage
# #packages
#
# # other libraries
# # packages <- c("rcpp", "parallel", "XML", "jasonlite", "httr", "shiny", "RMarkdown", "tm", "twitterR", "sqldf" "ROBDC", RMongo", "swirl", "reshape2", "qcc")
#
# ipak(packages)

# %% [markdown]
# ## R Programming Tutorial - Learn the Basics of Statistical Computing

# %%
library(IRdisplay)

  display_html("<iframe width='560' height='315' src='https://www.youtube.com/embed/_V8eKsto3Ug?rel=0&amp;controls=0&amp;showinfo=0'</iframe>")
# Out:
# <iframe width='560' height='315' src='https://www.youtube.com/embed/_V8eKsto3Ug?rel=0&amp;controls=0&amp;showinfo=0'</iframe>

# %% [markdown]
# - - -
# <!--NAVIGATION-->
# Module 13. [Introduction](./00.ipynb) | [Basic Syntax](./01.ipynb)  | [Data Types](./02.ipynb) | [Variables](./03.ipynb) | [Operators](./04.ipynb) | [Decision Making](./05.ipynb)  | [Functions](./06.ipynb) | [Strings](./07.ipynb) | [Vectors](./08.ipynb) | [Lists](./09.ipynb) | [Matrices](./10.ipynb) | [Arrays](./11.ipynb) | [Factors](./12.ipynb) | [Data Frames](./13.ipynb) | [Data Reshaping](./14.ipynb) | [Exercises](./15.ipynb)
